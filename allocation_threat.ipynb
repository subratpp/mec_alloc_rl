# %%
import numpy as np
import pandas as pd
import geopandas
import random
import matplotlib.pyplot as plt
import math
import seaborn as sns

from mip import *
import timeit

from stable_baselines3 import DQN

# %%
# Dataset and models
filename_base = 'dataset/dual_s_base.csv' #filename of data with only 1 user
# model_lin = DQN.load("edge_agent_30_lin")
# model_exp = DQN.load("edge_agent_30_exp")
model_act = DQN.load("edge_agent_action")
model_und = DQN.load("edge_agent_under_train")
model_prop = DQN.load("edge_agent_proper_train")

model_thres10 = DQN.load("edge_agent_thres10")

users_high = 19
users_low = 1 #to calculate the users numbers from action
users_res = 2

# %% [markdown]
# ### Utility Function to Load EUA Data

# %%
#Add data to users
def add_data(series): #not used now
    random_speed = random.uniform(0,1)
    if random_speed <= 0.3:
        series['Speed']= 0
    if random_speed > 0.3 and random_speed <= 0.6:   
        series['Speed']= random.uniform(1, 2)
    if random_speed > 0.6:
        series['Speed'] = random.uniform(10, 20)
    series['Direction']= random.randrange(0, 360, 10)
    qospref = [ random.randint(1,3), random.randint(1,3) ]
    qospref.sort()
    series['LowQoS'] = qospref[0]
    series['HighQoS'] = qospref[1]
    return series

#================Load Planet Lab data
def load_planetlab():
    #Convert to triangle
    ldata = np.loadtxt('PlanetLabData_1')[np.tril_indices(490)]
    ldata = ldata[ ldata != 0]
    ldata =np.unique(ldata)
    np.set_printoptions(suppress=True)
    length = ldata.shape[0]
    latency_row = 150
    latency_col = (length//latency_row) #Global Data used
    ldata = np.resize(ldata, latency_col*latency_row)
    latency = ldata.reshape(latency_row,-1)
    return latency

#=================Fetch Network latency
def fetch_network_lat(distance, latency_data):
    rep_lat = np.random.choice(latency_data[distance], size=1, replace=True)
    return rep_lat/1000 #convert latency to seconds
    

#===============User Data
def load_users(num_of_users):
    user_raw = pd.read_csv("eua/users.csv")
    user_raw = user_raw.rename_axis("UID")
    df = user_raw.sample(num_of_users)
#     user_raw = user_raw.reset_index()
    gdf = geopandas.GeoDataFrame(df, geometry = geopandas.points_from_xy(df.Longitude, df.Latitude), crs = {'init': 'epsg:4326'})
    user = gdf [['geometry']] #Keep Geometry column
    user = user.to_crs(epsg=28355) #Covert the format of data
    #Insert additional data to dataframe
    #user = user.apply(add_data, axis=1)
    return user

#================Server Data
def load_servers(num_of_servers):
    server_raw = pd.read_csv("eua/servers.csv")
    server_raw = server_raw.rename_axis("SID")
    df = server_raw.sample(num_of_servers) #Sample Servers Randomly
    gdf = geopandas.GeoDataFrame(df, geometry = geopandas.points_from_xy(df.LONGITUDE, df.LATITUDE), crs = {'init': 'epsg:4326'})
    server = gdf [['geometry']] #Keep Geometry column
    server = server.to_crs(epsg=28355) #Cover to crs in Australian EPSG
    def add_radius(series):
#         radius = random.randrange(150, 250, 10)
        radius = 150 #radus fixed to 150
        series.geometry = series.geometry.buffer(radius)
        series['radius'] = radius
#         series['resource'] = tcomp
        return series
    server = server.apply(add_radius, axis = 1)
    return server

#================neighbourhood Computing
def ngb_matrix(U, N, S): 
    #U: number of users
    #N: number of servers
    #S: number of services
    # U X N matrix
    user = load_users(U)
    server = load_servers(N)
    neighbourhood = np.zeros([U, N]) #matrix user(row) vs server(col)
    network_latency = np.zeros(N) #network latency for each server
    latency_data = load_planetlab() #load planetlad data, return matrix of bin size 150
    
    for u in range(0, U):
        for n in range(0, N):
            if server.iloc[n].geometry.contains(user.iloc[u].geometry):
                neighbourhood[u,n]=1
                #compute distance and assign latency
                distance = server.iloc[n].geometry.centroid.distance(user.iloc[u].geometry)
                rep_lat = fetch_network_lat(int(distance), latency_data) #fetch latency according to distance
                if network_latency[n] < rep_lat:
                    network_latency[n] = rep_lat
                
            else:
                neighbourhood[u,n]=0
    
    service = np.zeros(U)
    
    #assign service to the users
    for u in range(0, U):
        service[u] = random.randrange(0, S, 1) #generate a random service request to the user
        
    #find service request in each server
    server_service = np.zeros((N, S))
    
    #find the number of service request in each server
    for n in range(0, N):
        for u in range(0, U):
            if neighbourhood[u][n] == 1:
                server_service[n][int(service[u])] += 1
                
                
    
    return neighbourhood, user, server, service, server_service, network_latency

#Plot the user and server dataset on the map
def plot_data(user, server):
    # %config InlineBackend.figure_format='retina'
    # %matplotlib inline

    cbd = geopandas.read_file('eua/maps', crs = {'init': 'epsg=28355'} ) #read cbd-australia location data

    fig, ax = plt.subplots(1, 1, figsize=(15,10))
    ax.set_aspect('equal')

    ax.set_xlim(319400, 322100)
    ax.set_ylim(5811900, 5813700)

    user.plot(ax=ax, marker='o', color='red', markersize=20, zorder=3, label="users")
    server.plot(ax =ax, linestyle='dashed', edgecolor='green', linewidth=1, facecolor="none", zorder=1)
    server.centroid.plot(ax=ax, marker='s', color='blue', markersize=50, zorder=2, label="server")
    cbd.plot(ax=ax, color='grey', zorder=0, alpha = 0.3);

    ax.set_title("MEC Environment(EUA): CBD Melbourne(Australia)")
    ax.legend(bbox_to_anchor=(1, 0), loc='lower left')
    plt.show()

# %% [markdown]
# ## Load data for 1 user

# %%
def generate_server_state(num_server):
    df = pd.read_csv(filename_base)
    
#     df['ram'] = df['ram'].div(1000).round(0).astype(int)
#     df['workload_cpu'] = df['workload_cpu'].div(10).round(0).astype(int)
    df['workload_gpu'] = df['workload_gpu'].multiply(1/80).round(0).astype(int) #round gpu workload
#     df['users_yolo'] = df['users_yolo'].div(100).round(0).astype(int)
#     df['users_mnet'] = df['users_mnet'].div(100).round(0).astype(int)
    
    
    #get unique data in set
    ram = df.ram.unique()
    cores = df.cores.unique()
    workload_cpu = df.workload_cpu.unique()

    
    server_state = []
    gamma = []
    
    for s_id in range(num_server):
        #generate unique state
        gram = np.random.choice(ram, 1)[0]
        gcores = np.random.choice(cores, 1)[0]
        gwl_c = np.random.choice(workload_cpu, 1)[0]
    
        
       
        #fetch gamma for the state
        fetch_state = df.loc[ (df['ram'] == gram) & (df['cores']== gcores) & (df['workload_cpu']==gwl_c) ]
       
        gwl_g = fetch_state.sample().iloc[0]['workload_gpu'] #fetch workload randmoly
        fetch_time = fetch_state.loc[ (df['workload_gpu'] == gwl_g) ]
        
        time_yolo = fetch_time['time_yolo'].mean() #average of time for particular state
        time_mnet = fetch_time['time_mnet'].mean()
        
        gs1 = server_service[s_id][0] #assignt the state according to service request to each server
        gs2 = server_service[s_id][1] 
        server_state.append( [gram, gcores, gwl_c, gwl_g, gs1, gs2] )
        
        gamma.append((time_yolo, time_mnet)) #append the gamma value of each server
    
    return server_state, gamma

# %% [markdown]
# # Algorithms

# %% [markdown]
# ### ILP Algorithm

# %%
def ilp_algo():
    ## ===================================ILP with python mip
    # >> solver_name=GRB
    # >> Currently using CBC
    I = range(U) #user
    J = range(N) #server

    alloc = Model(sense=MAXIMIZE, name="alloc")

    def coverage(user_ix, server_ix):
        if ngb[user_ix][server_ix]==1:
            return 1
        else:
            return 0

    #U: num of users, N: num of servers
    x = [[ alloc.add_var(f"x{i}{j}", var_type=BINARY) for j in J] for i in I]

    #Objective Equation
    alloc.objective = xsum( x[i][j]  for i in I for j in J )

    #1 .Coverage Constraint
    for i in I:
        for j in J:        
                if not coverage(i,j):
                    alloc += x[i][j] == 0

    #2. User allocation to single server constrain
    for i in I:
        alloc += xsum( x[i][j] for j in J ) <=1

    #3. Latency Constraint
    for j in J:
        alloc += xsum( gamma[j][int(service[i])]*x[i][j] for i in I ) <=latency_threshold-network_latency[j] 

    #alloc.write("test-model.lp")

    #===========Start Optimization=========
    alloc.optimize(max_seconds=25)

    #==========ILP Ends here
    #print(f"Number of Solutions:{qoe.num_solutions}")
    ilp_allocation = [ (i,j) for i in I for j in J if x[i][j].x >= 0.99]

    #print(f"Number of Solutions:{qoe.num_solutions}")
    #print(f"Objective Value:{qoe.objective_value}")
    allocated_num_users = len(ilp_allocation)
    print("ILP Allocated Num of Users: {}".format(allocated_num_users))
    # selected.sort()
    return ilp_allocation

# %% [markdown]
# ### RL Allocation Algorithm

# %%
#Load model
def rl_algo_prop():
    #for each server find the number of possible users using model
    server_capacity = np.zeros((N, S))
    for server_id in range(N):
        state = server_state[server_id]
        
        action = model_prop.predict(np.array(state), deterministic=True)
        
        u1 = (action[0]//10)*2 + 1
        u2 = (action[0]%10)*2 + 1
        server_capacity[server_id][0] = u1 #model output
        server_capacity[server_id][1] = u2 #model output
    
    #sort with number of servers per user
    col1 = np.array([np.sum(ngb,axis=1)])
    col2 = np.array([np.arange(U)])
    sorted_ngb = np.concatenate((ngb, col1.T, col2.T), axis=1) #add rowsum and index column
    sorted_ngb = sorted_ngb[np.argsort(sorted_ngb[:, N])] #sort the rows based on rowsum column

    #allocation heuristic
    #run allocation algorithm
    rl_allocation = []

    for i in range(U):
        server_list = np.where(sorted_ngb[i, :N] == 1)[0] #get the list of server to which user is connected

        if len(server_list) == 0: #skip users with no server
            continue
        
        ser = int(service[i]) #which service user is requesting
        choosen_server = server_list[np.argmax(server_capacity[server_list, ser])] #find the id of choosen server
        
        
        if  server_capacity[choosen_server][ser] > 0: #assigning user to choosen_server
            server_capacity[choosen_server][ser] -= 1 #decrement the server capacity

            rl_allocation.append( (int(sorted_ngb[i, N+1]), choosen_server) ) #(user, server) alloc pair
    print('RL Num of allocation: {}'.format(len(rl_allocation)))

    return rl_allocation

# %%
#Load model
def rl_algo_und():
    #for each server find the number of possible users using model
    server_capacity = np.zeros((N, S))
    for server_id in range(N):
        state = server_state[server_id]
        
        action = model_und.predict(np.array(state), deterministic=True)
        
        u1 = (action[0]//10)*2 + 1
        u2 = (action[0]%10)*2 + 1
        server_capacity[server_id][0] = u1 #model output
        server_capacity[server_id][1] = u2 #model output
    
    #sort with number of servers per user
    col1 = np.array([np.sum(ngb,axis=1)])
    col2 = np.array([np.arange(U)])
    sorted_ngb = np.concatenate((ngb, col1.T, col2.T), axis=1) #add rowsum and index column
    sorted_ngb = sorted_ngb[np.argsort(sorted_ngb[:, N])] #sort the rows based on rowsum column

    #allocation heuristic
    #run allocation algorithm
    rl_allocation = []

    for i in range(U):
        server_list = np.where(sorted_ngb[i, :N] == 1)[0] #get the list of server to which user is connected

        if len(server_list) == 0: #skip users with no server
            continue
        
        ser = int(service[i]) #which service user is requesting
        choosen_server = server_list[np.argmax(server_capacity[server_list, ser])] #find the id of choosen server
        
        
        if  server_capacity[choosen_server][ser] > 0: #assigning user to choosen_server
            server_capacity[choosen_server][ser] -= 1 #decrement the server capacity

            rl_allocation.append( (int(sorted_ngb[i, N+1]), choosen_server) ) #(user, server) alloc pair
    print('RL Num of allocation: {}'.format(len(rl_allocation)))

    return rl_allocation

# %%
#Load model
def rl_algo_act():
    #for each server find the number of possible users using model
    server_capacity = np.zeros((N, S))
    for server_id in range(N):
        state = server_state[server_id]
        
        action = model_act.predict(np.array(state), deterministic=True)
        
        u1 = (action[0]//5)*4 + 1 #25 action space
        u2 = (action[0]%5)*4 + 1
        server_capacity[server_id][0] = u1 #model output
        server_capacity[server_id][1] = u2 #model output
    
    #sort with number of servers per user
    col1 = np.array([np.sum(ngb,axis=1)])
    col2 = np.array([np.arange(U)])
    sorted_ngb = np.concatenate((ngb, col1.T, col2.T), axis=1) #add rowsum and index column
    sorted_ngb = sorted_ngb[np.argsort(sorted_ngb[:, N])] #sort the rows based on rowsum column

    #allocation heuristic
    #run allocation algorithm
    rl_allocation = []

    for i in range(U):
        server_list = np.where(sorted_ngb[i, :N] == 1)[0] #get the list of server to which user is connected

        if len(server_list) == 0: #skip users with no server
            continue
        
        ser = int(service[i]) #which service user is requesting
        choosen_server = server_list[np.argmax(server_capacity[server_list, ser])] #find the id of choosen server
        
        
        if  server_capacity[choosen_server][ser] > 0: #assigning user to choosen_server
            server_capacity[choosen_server][ser] -= 1 #decrement the server capacity

            rl_allocation.append( (int(sorted_ngb[i, N+1]), choosen_server) ) #(user, server) alloc pair
    print('RL Num of allocation: {}'.format(len(rl_allocation)))

    return rl_allocation

# %%
#Load model
def rl_algo_thres10():
    users_high = 500
    users_low = 100 #to calculate the users numbers from action
    users_res = 100
    #for each server find the number of possible users using model
    server_capacity = np.zeros((N, S))
    for server_id in range(N):
        state = server_state[server_id]
#         if model_type == 'lin':
        action = model_thres10.predict(np.array(state), deterministic=True)
#         if model_type == 'exp':
#             action = model_exp.predict(np.array(state), deterministic=True)
        u1 = action[0]//5 + 1
        u2 = (action[0]+1) - (u1-1)*5
        server_capacity[server_id][0] = u1*100 #model output
        server_capacity[server_id][1] = u2*100 #model output
    
    #sort with number of servers per user
    col1 = np.array([np.sum(ngb,axis=1)])
    col2 = np.array([np.arange(U)])
    sorted_ngb = np.concatenate((ngb, col1.T, col2.T), axis=1) #add rowsum and index column
    sorted_ngb = sorted_ngb[np.argsort(sorted_ngb[:, N])] #sort the rows based on rowsum column

    #allocation heuristic
    #run allocation algorithm
    rl_allocation = []

    for i in range(U):
        server_list = np.where(sorted_ngb[i, :N] == 1)[0] #get the list of server to which user is connected

        if len(server_list) == 0: #skip users with no server
            continue
        
        ser = int(service[i]) #which service user is requesting
        choosen_server = server_list[np.argmax(server_capacity[server_list, ser])] #find the id of choosen server
        
        
        if  server_capacity[choosen_server][ser] > 0: #assigning user to choosen_server
            server_capacity[choosen_server][ser] -= 1 #decrement the server capacity

            rl_allocation.append( (int(sorted_ngb[i, N+1]), choosen_server) ) #(user, server) alloc pair
    print('RL Num of allocation: {}'.format(len(rl_allocation)))

    return rl_allocation

# %% [markdown]
# ### Nearest Ngb Greedy Algorithm

# %%
def greedy_algo():
    server_capacity = np.zeros(N)
    rl_allocation = []
    for user_id in range(U):
        server_ngb_list = np.where(ngb[user_id, :N] == 1)[0] #get the list of server to which user is connected
        if len(server_ngb_list) == 0: #ignore the users which are not under any servers
            continue 
    
        #find the distance to each users in the server_ngb_list
        dist_list = np.array([ server_ngb_list, [server.iloc[i]['geometry'].centroid.distance(user.iloc[user_id]['geometry']) for i in server_ngb_list] ])
        # sorted list of servers based on the distance from users
        sorted_distance_list = dist_list[ :, dist_list[1].argsort()]
        #get the list of servers arranged in least to max distance
        server_list = sorted_distance_list[0].astype(int)
        
        lat = 0
        for server_id in server_list:
            lat = gamma[server_id][int(service[user_id])]
            if server_capacity[server_id]+lat <= latency_threshold-network_latency[server_id]:
                server_capacity[server_id] += lat #increment the server_capacity of server
                rl_allocation.append( (user_id, server_id) ) #(user, server) alloc pair
                break
    
    print('Greedy-Ngb Num of allocation: {}'.format(len(rl_allocation)))
    return rl_allocation

# %% [markdown]
# ## Test

# %%
# U = 500
# N = 50
# S = 2
# latency_threshold = 50
# ngb, user, server, service, server_service = ngb_matrix(U, N, S)
# server_state, gamma = generate_server_state(N)

# %% [markdown]
# ## Result Dataset

# %%
#Result file details
# result_file = 'allocation_results/allocation_for_s50_thres30.csv'
result_file = 'allocation_results/allocation_for_threats_s30.csv'
column_names = ["user", "server", 
                "ilp_user", "ilp_time",
                "greedy_user", "greedy_time",
                "rl_act_user", "rl_act_time",
                "rl_und_user", "rl_und_time",
                "rl_prop_user", "rl_prop_time",
                "rl_thres10_user", "rl_thres10_time", 
               ]
result_user = pd.DataFrame(columns = column_names)
result_user.to_csv(result_file, index=False)
result_user = pd.read_csv(result_file)

# %% [markdown]
# # main()

# %%
latency_threshold = 10
N = 30
S = 2 #number of services
for U in range(100, 600, 100):
#     for N in range(20, 100, 20):
    for epoch in range(50):
        print("User:", U, 'Server:', N, 'Epoch:', epoch)
#             U = 50 #Number of users #Define U, N and ngb Matrix
#             N = 10 #Number of Servers
        ngb, user, server, service, server_service, network_latency = ngb_matrix(U, N, S) #generate server and user from EUA data #determine neighbourhood matrix
        server_state, gamma = generate_server_state(N) #assign state and gamma for each user

        #=======ILP starts
        start = 0
        stop = 0
        execution_time_ilp = 0
        start = timeit.default_timer()

        ilp_aloc = ilp_algo() #call ILP algorithm

        stop = timeit.default_timer()
        execution_time_ilp = stop - start
        #========ILP ends
        
        #=======Greedy starts
        start = 0
        stop = 0
        execution_time_greedy = 0
        start = timeit.default_timer()

        greedy_aloc = greedy_algo() #call ILP algorithm

        stop = timeit.default_timer()
        execution_time_greedy = stop - start
        #========Greedy ends

        #=======RL_action
        start = 0
        stop = 0
        execution_time_rl_act = 0
        start = timeit.default_timer()

        rl_act_aloc = rl_algo_act() #call ILP algorithm

        stop = timeit.default_timer()
        execution_time_rl_act = stop - start
        #========RL_linear ends
        
        #=======RL_under train
        start = 0
        stop = 0
        execution_time_rl_und = 0
        start = timeit.default_timer()

        rl_und_aloc = rl_algo_und() #call ILP algorithm

        stop = timeit.default_timer()
        execution_time_rl_und = stop - start
        #========RL_utrain ends
        
        #=======RL_propertrain
        start = 0
        stop = 0
        execution_time_rl_prop = 0
        start = timeit.default_timer()

        rl_prop_aloc = rl_algo_prop() #call ILP algorithm

        stop = timeit.default_timer()
        execution_time_rl_prop = stop - start
        #========RL_utrain ends
        
        
        #=======RL_thres10
        start = 0
        stop = 0
        execution_time_rl_thres10 = 0
        start = timeit.default_timer()

        rl_thres10_aloc = rl_algo_thres10() #call ILP algorithm

        stop = timeit.default_timer()
        execution_time_rl_thres10 = stop - start
        #========RL_ends

        #========Store results to file
        to_append = [U, N,
                     len(ilp_aloc), execution_time_ilp,
                     len(greedy_aloc), execution_time_greedy,
                     len(rl_act_aloc), execution_time_rl_act,
                     len(rl_und_aloc), execution_time_rl_und,
                     len(rl_prop_aloc), execution_time_rl_prop,
                     len(rl_thres10_aloc), execution_time_rl_thres10,
                    ] 
        dseries = pd.Series(to_append, index = result_user.columns)
        result_user = result_user.append(dseries, ignore_index=True)
        print("epoch:", epoch)
result_user.to_csv(result_file, index=False)
# Out:
# User: 100 Server: 30 Epoch: 0
# ILP Allocated Num of Users: 45
# Greedy-Ngb Num of allocation: 41
# RL Num of allocation: 77
# RL Num of allocation: 70
# RL Num of allocation: 77
# RL Num of allocation: 77
# epoch: 0
# User: 100 Server: 30 Epoch: 1
# ILP Allocated Num of Users: 42
# Greedy-Ngb Num of allocation: 41
# RL Num of allocation: 50
# RL Num of allocation: 49
# RL Num of allocation: 50
# RL Num of allocation: 50
# epoch: 1
# User: 100 Server: 30 Epoch: 2
# ILP Allocated Num of Users: 40
# Greedy-Ngb Num of allocation: 35
# RL Num of allocation: 63
# RL Num of allocation: 59
# RL Num of allocation: 64
# RL Num of allocation: 64
# epoch: 2
# User: 100 Server: 30 Epoch: 3
# ILP Allocated Num of Users: 43
# Greedy-Ngb Num of allocation: 42
# RL Num of allocation: 70
# RL Num of allocation: 67
# RL Num of allocation: 70
# RL Num of allocation: 70
# epoch: 3
# User: 100 Server: 30 Epoch: 4
# ILP Allocated Num of Users: 51
# Greedy-Ngb Num of allocation: 43
# RL Num of allocation: 75
# RL Num of allocation: 72
# RL Num of allocation: 75
# RL Num of allocation: 75
# epoch: 4
# User: 100 Server: 30 Epoch: 5
# ILP Allocated Num of Users: 46
# Greedy-Ngb Num of allocation: 44
# RL Num of allocation: 73
# RL Num of allocation: 68
# RL Num of allocation: 73
# RL Num of allocation: 73
# epoch: 5
# User: 100 Server: 30 Epoch: 6
# ILP Allocated Num of Users: 44
# Greedy-Ngb Num of allocation: 43
# RL Num of allocation: 62
# RL Num of allocation: 52
# RL Num of allocation: 62
# RL Num of allocation: 62
# epoch: 6
# User: 100 Server: 30 Epoch: 7
# ILP Allocated Num of Users: 43
# Greedy-Ngb Num of allocation: 41
# RL Num of allocation: 66
# RL Num of allocation: 55
# RL Num of allocation: 68
# RL Num of allocation: 68
# epoch: 7
# User: 100 Server: 30 Epoch: 8
# ILP Allocated Num of Users: 39
# Greedy-Ngb Num of allocation: 35
# RL Num of allocation: 63
# RL Num of allocation: 55
# RL Num of allocation: 63
# RL Num of allocation: 63
# epoch: 8
# User: 100 Server: 30 Epoch: 9
# ILP Allocated Num of Users: 44
# Greedy-Ngb Num of allocation: 44
# RL Num of allocation: 56
# RL Num of allocation: 51
# RL Num of allocation: 56
# RL Num of allocation: 56
# epoch: 9
# User: 100 Server: 30 Epoch: 10
# ILP Allocated Num of Users: 49
# Greedy-Ngb Num of allocation: 44
# RL Num of allocation: 79
# RL Num of allocation: 73
# RL Num of allocation: 79
# RL Num of allocation: 79
# epoch: 10
# User: 100 Server: 30 Epoch: 11
# ILP Allocated Num of Users: 38
# Greedy-Ngb Num of allocation: 32
# RL Num of allocation: 65
# RL Num of allocation: 54
# RL Num of allocation: 65
# RL Num of allocation: 65
# epoch: 11
# User: 100 Server: 30 Epoch: 12
# ILP Allocated Num of Users: 48
# Greedy-Ngb Num of allocation: 46
# RL Num of allocation: 65
# RL Num of allocation: 63
# RL Num of allocation: 65
# RL Num of allocation: 65
# epoch: 12
# User: 100 Server: 30 Epoch: 13
# ILP Allocated Num of Users: 46
# Greedy-Ngb Num of allocation: 42
# RL Num of allocation: 65
# RL Num of allocation: 62
# RL Num of allocation: 65
# RL Num of allocation: 65
# epoch: 13
# User: 100 Server: 30 Epoch: 14
# ILP Allocated Num of Users: 43
# Greedy-Ngb Num of allocation: 41
# RL Num of allocation: 72
# RL Num of allocation: 66
# RL Num of allocation: 72
# RL Num of allocation: 72
# epoch: 14
# User: 100 Server: 30 Epoch: 15
# ILP Allocated Num of Users: 43
# Greedy-Ngb Num of allocation: 42
# RL Num of allocation: 60
# RL Num of allocation: 58
# RL Num of allocation: 60
# RL Num of allocation: 60
# epoch: 15
# User: 100 Server: 30 Epoch: 16
# ILP Allocated Num of Users: 46
# Greedy-Ngb Num of allocation: 45
# RL Num of allocation: 71
# RL Num of allocation: 66
# RL Num of allocation: 71
# RL Num of allocation: 71
# epoch: 16
# User: 100 Server: 30 Epoch: 17
# ILP Allocated Num of Users: 42
# Greedy-Ngb Num of allocation: 37
# RL Num of allocation: 63
# RL Num of allocation: 57
# RL Num of allocation: 63
# RL Num of allocation: 63
# epoch: 17
# User: 100 Server: 30 Epoch: 18
# ILP Allocated Num of Users: 48
# Greedy-Ngb Num of allocation: 45
# RL Num of allocation: 65
# RL Num of allocation: 59
# RL Num of allocation: 65
# RL Num of allocation: 65
# epoch: 18
# User: 100 Server: 30 Epoch: 19
# ILP Allocated Num of Users: 45
# Greedy-Ngb Num of allocation: 41
# RL Num of allocation: 62
# RL Num of allocation: 58
# RL Num of allocation: 62
# RL Num of allocation: 62
# epoch: 19
# User: 100 Server: 30 Epoch: 20
# ILP Allocated Num of Users: 46
# Greedy-Ngb Num of allocation: 42
# RL Num of allocation: 63
# RL Num of allocation: 53
# RL Num of allocation: 63
# RL Num of allocation: 63
# epoch: 20
# User: 100 Server: 30 Epoch: 21
# ILP Allocated Num of Users: 37
# Greedy-Ngb Num of allocation: 34
# RL Num of allocation: 61
# RL Num of allocation: 56
# RL Num of allocation: 61
# RL Num of allocation: 61
# epoch: 21
# User: 100 Server: 30 Epoch: 22
# ILP Allocated Num of Users: 44
# Greedy-Ngb Num of allocation: 40
# RL Num of allocation: 62
# RL Num of allocation: 61
# RL Num of allocation: 62
# RL Num of allocation: 62
# epoch: 22
# User: 100 Server: 30 Epoch: 23
# ILP Allocated Num of Users: 45
# Greedy-Ngb Num of allocation: 44
# RL Num of allocation: 65
# RL Num of allocation: 53
# RL Num of allocation: 65
# RL Num of allocation: 65
# epoch: 23
# User: 100 Server: 30 Epoch: 24
# ILP Allocated Num of Users: 49
# Greedy-Ngb Num of allocation: 45
# RL Num of allocation: 67
# RL Num of allocation: 61
# RL Num of allocation: 67
# RL Num of allocation: 67
# epoch: 24
# User: 100 Server: 30 Epoch: 25
# ILP Allocated Num of Users: 45
# Greedy-Ngb Num of allocation: 41
# RL Num of allocation: 69
# RL Num of allocation: 57
# RL Num of allocation: 69
# RL Num of allocation: 69
# epoch: 25
# User: 100 Server: 30 Epoch: 26
# ILP Allocated Num of Users: 46
# Greedy-Ngb Num of allocation: 41
# RL Num of allocation: 61
# RL Num of allocation: 59
# RL Num of allocation: 61
# RL Num of allocation: 61
# epoch: 26
# User: 100 Server: 30 Epoch: 27
# ILP Allocated Num of Users: 52
# Greedy-Ngb Num of allocation: 47
# RL Num of allocation: 76
# RL Num of allocation: 67
# RL Num of allocation: 76
# RL Num of allocation: 76
# epoch: 27
# User: 100 Server: 30 Epoch: 28
# ILP Allocated Num of Users: 43
# Greedy-Ngb Num of allocation: 41
# RL Num of allocation: 66
# RL Num of allocation: 63
# RL Num of allocation: 66
# RL Num of allocation: 66
# epoch: 28
# User: 100 Server: 30 Epoch: 29
# ILP Allocated Num of Users: 44
# Greedy-Ngb Num of allocation: 44
# RL Num of allocation: 68
# RL Num of allocation: 64
# RL Num of allocation: 68
# RL Num of allocation: 68
# epoch: 29
# User: 100 Server: 30 Epoch: 30
# ILP Allocated Num of Users: 48
# Greedy-Ngb Num of allocation: 44
# RL Num of allocation: 69
# RL Num of allocation: 64
# RL Num of allocation: 69
# RL Num of allocation: 69
# epoch: 30
# User: 100 Server: 30 Epoch: 31
# ILP Allocated Num of Users: 36
# Greedy-Ngb Num of allocation: 34
# RL Num of allocation: 56
# RL Num of allocation: 49
# RL Num of allocation: 56
# RL Num of allocation: 56
# epoch: 31
# User: 100 Server: 30 Epoch: 32
# ILP Allocated Num of Users: 48
# Greedy-Ngb Num of allocation: 46
# RL Num of allocation: 66
# RL Num of allocation: 56
# RL Num of allocation: 66
# RL Num of allocation: 66
# epoch: 32
# User: 100 Server: 30 Epoch: 33
# ILP Allocated Num of Users: 44
# Greedy-Ngb Num of allocation: 41
# RL Num of allocation: 61
# RL Num of allocation: 56
# RL Num of allocation: 61
# RL Num of allocation: 61
# epoch: 33
# User: 100 Server: 30 Epoch: 34
# ILP Allocated Num of Users: 39
# Greedy-Ngb Num of allocation: 39
# RL Num of allocation: 60
# RL Num of allocation: 57
# RL Num of allocation: 60
# RL Num of allocation: 60
# epoch: 34
# User: 100 Server: 30 Epoch: 35
# ILP Allocated Num of Users: 44
# Greedy-Ngb Num of allocation: 42
# RL Num of allocation: 66
# RL Num of allocation: 55
# RL Num of allocation: 66
# RL Num of allocation: 66
# epoch: 35
# User: 100 Server: 30 Epoch: 36
# ILP Allocated Num of Users: 48
# Greedy-Ngb Num of allocation: 43
# RL Num of allocation: 76
# RL Num of allocation: 68
# RL Num of allocation: 76
# RL Num of allocation: 76
# epoch: 36
# User: 100 Server: 30 Epoch: 37
# ILP Allocated Num of Users: 38
# Greedy-Ngb Num of allocation: 37
# RL Num of allocation: 59
# RL Num of allocation: 57
# RL Num of allocation: 59
# RL Num of allocation: 59
# epoch: 37
# User: 100 Server: 30 Epoch: 38
# ILP Allocated Num of Users: 41
# Greedy-Ngb Num of allocation: 38
# RL Num of allocation: 58
# RL Num of allocation: 55
# RL Num of allocation: 58
# RL Num of allocation: 58
# epoch: 38
# User: 100 Server: 30 Epoch: 39
# ILP Allocated Num of Users: 40
# Greedy-Ngb Num of allocation: 39
# RL Num of allocation: 56
# RL Num of allocation: 53
# RL Num of allocation: 56
# RL Num of allocation: 56
# epoch: 39
# User: 100 Server: 30 Epoch: 40
# ILP Allocated Num of Users: 44
# Greedy-Ngb Num of allocation: 41
# RL Num of allocation: 67
# RL Num of allocation: 66
# RL Num of allocation: 67
# RL Num of allocation: 67
# epoch: 40
# User: 100 Server: 30 Epoch: 41
# ILP Allocated Num of Users: 43
# Greedy-Ngb Num of allocation: 38
# RL Num of allocation: 67
# RL Num of allocation: 63
# RL Num of allocation: 67
# RL Num of allocation: 67
# epoch: 41
# User: 100 Server: 30 Epoch: 42
# ILP Allocated Num of Users: 39
# Greedy-Ngb Num of allocation: 35
# RL Num of allocation: 49
# RL Num of allocation: 49
# RL Num of allocation: 49
# RL Num of allocation: 49
# epoch: 42
# User: 100 Server: 30 Epoch: 43
# ILP Allocated Num of Users: 40
# Greedy-Ngb Num of allocation: 37
# RL Num of allocation: 63
# RL Num of allocation: 57
# RL Num of allocation: 64
# RL Num of allocation: 64
# epoch: 43
# User: 100 Server: 30 Epoch: 44
# ILP Allocated Num of Users: 50
# Greedy-Ngb Num of allocation: 46
# RL Num of allocation: 72
# RL Num of allocation: 69
# RL Num of allocation: 72
# RL Num of allocation: 72
# epoch: 44
# User: 100 Server: 30 Epoch: 45
# ILP Allocated Num of Users: 46
# Greedy-Ngb Num of allocation: 43
# RL Num of allocation: 72
# RL Num of allocation: 67
# RL Num of allocation: 72
# RL Num of allocation: 72
# epoch: 45
# User: 100 Server: 30 Epoch: 46
# ILP Allocated Num of Users: 46
# Greedy-Ngb Num of allocation: 45
# RL Num of allocation: 64
# RL Num of allocation: 60
# RL Num of allocation: 64
# RL Num of allocation: 64
# epoch: 46
# User: 100 Server: 30 Epoch: 47
# ILP Allocated Num of Users: 41
# Greedy-Ngb Num of allocation: 40
# RL Num of allocation: 63
# RL Num of allocation: 61
# RL Num of allocation: 63
# RL Num of allocation: 63
# epoch: 47
# User: 100 Server: 30 Epoch: 48
# ILP Allocated Num of Users: 38
# Greedy-Ngb Num of allocation: 36
# RL Num of allocation: 56
# RL Num of allocation: 56
# RL Num of allocation: 56
# RL Num of allocation: 56
# epoch: 48
# User: 100 Server: 30 Epoch: 49
# ILP Allocated Num of Users: 49
# Greedy-Ngb Num of allocation: 46
# RL Num of allocation: 72
# RL Num of allocation: 64
# RL Num of allocation: 73
# RL Num of allocation: 73
# epoch: 49
# User: 200 Server: 30 Epoch: 0
# ILP Allocated Num of Users: 59
# Greedy-Ngb Num of allocation: 52
# RL Num of allocation: 128
# RL Num of allocation: 121
# RL Num of allocation: 129
# RL Num of allocation: 129
# epoch: 0
# User: 200 Server: 30 Epoch: 1
# ILP Allocated Num of Users: 64
# Greedy-Ngb Num of allocation: 54
# RL Num of allocation: 104
# RL Num of allocation: 99
# RL Num of allocation: 104
# RL Num of allocation: 104
# epoch: 1
# User: 200 Server: 30 Epoch: 2
# ILP Allocated Num of Users: 62
# Greedy-Ngb Num of allocation: 53
# RL Num of allocation: 142
# RL Num of allocation: 119
# RL Num of allocation: 144
# RL Num of allocation: 144
# epoch: 2
# User: 200 Server: 30 Epoch: 3
# ILP Allocated Num of Users: 55
# Greedy-Ngb Num of allocation: 46
# RL Num of allocation: 125
# RL Num of allocation: 107
# RL Num of allocation: 125
# RL Num of allocation: 125
# epoch: 3
# User: 200 Server: 30 Epoch: 4
# ILP Allocated Num of Users: 62
# Greedy-Ngb Num of allocation: 55
# RL Num of allocation: 128
# RL Num of allocation: 110
# RL Num of allocation: 129
# RL Num of allocation: 129
# epoch: 4
# User: 200 Server: 30 Epoch: 5
# ILP Allocated Num of Users: 63
# Greedy-Ngb Num of allocation: 53
# RL Num of allocation: 132
# RL Num of allocation: 115
# RL Num of allocation: 132
# RL Num of allocation: 132
# epoch: 5
# User: 200 Server: 30 Epoch: 6
# ILP Allocated Num of Users: 63
# Greedy-Ngb Num of allocation: 56
# RL Num of allocation: 111
# RL Num of allocation: 94
# RL Num of allocation: 111
# RL Num of allocation: 111
# epoch: 6
# User: 200 Server: 30 Epoch: 7
# ILP Allocated Num of Users: 55
# Greedy-Ngb Num of allocation: 49
# RL Num of allocation: 112
# RL Num of allocation: 100
# RL Num of allocation: 112
# RL Num of allocation: 112
# epoch: 7
# User: 200 Server: 30 Epoch: 8
# ILP Allocated Num of Users: 58
# Greedy-Ngb Num of allocation: 51
# RL Num of allocation: 109
# RL Num of allocation: 104
# RL Num of allocation: 111
# RL Num of allocation: 111
# epoch: 8
# User: 200 Server: 30 Epoch: 9
# ILP Allocated Num of Users: 51
# Greedy-Ngb Num of allocation: 45
# RL Num of allocation: 118
# RL Num of allocation: 98
# RL Num of allocation: 118
# RL Num of allocation: 118
# epoch: 9
# User: 200 Server: 30 Epoch: 10
# ILP Allocated Num of Users: 57
# Greedy-Ngb Num of allocation: 51
# RL Num of allocation: 126
# RL Num of allocation: 99
# RL Num of allocation: 126
# RL Num of allocation: 126
# epoch: 10
# User: 200 Server: 30 Epoch: 11
# ILP Allocated Num of Users: 63
# Greedy-Ngb Num of allocation: 53
# RL Num of allocation: 127
# RL Num of allocation: 120
# RL Num of allocation: 130
# RL Num of allocation: 130
# epoch: 11
# User: 200 Server: 30 Epoch: 12
# ILP Allocated Num of Users: 59
# Greedy-Ngb Num of allocation: 52
# RL Num of allocation: 127
# RL Num of allocation: 106
# RL Num of allocation: 132
# RL Num of allocation: 132
# epoch: 12
# User: 200 Server: 30 Epoch: 13
# ILP Allocated Num of Users: 60
# Greedy-Ngb Num of allocation: 50
# RL Num of allocation: 116
# RL Num of allocation: 111
# RL Num of allocation: 123
# RL Num of allocation: 123
# epoch: 13
# User: 200 Server: 30 Epoch: 14
# ILP Allocated Num of Users: 61
# Greedy-Ngb Num of allocation: 49
# RL Num of allocation: 136
# RL Num of allocation: 114
# RL Num of allocation: 137
# RL Num of allocation: 137
# epoch: 14
# User: 200 Server: 30 Epoch: 15
# ILP Allocated Num of Users: 55
# Greedy-Ngb Num of allocation: 48
# RL Num of allocation: 135
# RL Num of allocation: 120
# RL Num of allocation: 139
# RL Num of allocation: 139
# epoch: 15
# User: 200 Server: 30 Epoch: 16
# ILP Allocated Num of Users: 59
# Greedy-Ngb Num of allocation: 50
# RL Num of allocation: 138
# RL Num of allocation: 115
# RL Num of allocation: 138
# RL Num of allocation: 138
# epoch: 16
# User: 200 Server: 30 Epoch: 17
# ILP Allocated Num of Users: 63
# Greedy-Ngb Num of allocation: 56
# RL Num of allocation: 133
# RL Num of allocation: 115
# RL Num of allocation: 135
# RL Num of allocation: 135
# epoch: 17
# User: 200 Server: 30 Epoch: 18
# ILP Allocated Num of Users: 58
# Greedy-Ngb Num of allocation: 55
# RL Num of allocation: 115
# RL Num of allocation: 106
# RL Num of allocation: 115
# RL Num of allocation: 115
# epoch: 18
# User: 200 Server: 30 Epoch: 19
# ILP Allocated Num of Users: 54
# Greedy-Ngb Num of allocation: 45
# RL Num of allocation: 124
# RL Num of allocation: 111
# RL Num of allocation: 126
# RL Num of allocation: 126
# epoch: 19
# User: 200 Server: 30 Epoch: 20
# ILP Allocated Num of Users: 62
# Greedy-Ngb Num of allocation: 54
# RL Num of allocation: 128
# RL Num of allocation: 111
# RL Num of allocation: 128
# RL Num of allocation: 128
# epoch: 20
# User: 200 Server: 30 Epoch: 21
# ILP Allocated Num of Users: 59
# Greedy-Ngb Num of allocation: 49
# RL Num of allocation: 145
# RL Num of allocation: 111
# RL Num of allocation: 147
# RL Num of allocation: 147
# epoch: 21
# User: 200 Server: 30 Epoch: 22
# ILP Allocated Num of Users: 61
# Greedy-Ngb Num of allocation: 55
# RL Num of allocation: 136
# RL Num of allocation: 121
# RL Num of allocation: 139
# RL Num of allocation: 139
# epoch: 22
# User: 200 Server: 30 Epoch: 23
# ILP Allocated Num of Users: 58
# Greedy-Ngb Num of allocation: 51
# RL Num of allocation: 146
# RL Num of allocation: 123
# RL Num of allocation: 146
# RL Num of allocation: 146
# epoch: 23
# User: 200 Server: 30 Epoch: 24
# ILP Allocated Num of Users: 60
# Greedy-Ngb Num of allocation: 51
# RL Num of allocation: 116
# RL Num of allocation: 107
# RL Num of allocation: 116
# RL Num of allocation: 116
# epoch: 24
# User: 200 Server: 30 Epoch: 25
# ILP Allocated Num of Users: 52
# Greedy-Ngb Num of allocation: 45
# RL Num of allocation: 117
# RL Num of allocation: 94
# RL Num of allocation: 118
# RL Num of allocation: 118
# epoch: 25
# User: 200 Server: 30 Epoch: 26
# ILP Allocated Num of Users: 59
# Greedy-Ngb Num of allocation: 53
# RL Num of allocation: 146
# RL Num of allocation: 142
# RL Num of allocation: 148
# RL Num of allocation: 148
# epoch: 26
# User: 200 Server: 30 Epoch: 27
# ILP Allocated Num of Users: 63
# Greedy-Ngb Num of allocation: 55
# RL Num of allocation: 108
# RL Num of allocation: 98
# RL Num of allocation: 108
# RL Num of allocation: 108
# epoch: 27
# User: 200 Server: 30 Epoch: 28
# ILP Allocated Num of Users: 65
# Greedy-Ngb Num of allocation: 54
# RL Num of allocation: 124
# RL Num of allocation: 117
# RL Num of allocation: 126
# RL Num of allocation: 126
# epoch: 28
# User: 200 Server: 30 Epoch: 29
# ILP Allocated Num of Users: 59
# Greedy-Ngb Num of allocation: 53
# RL Num of allocation: 130
# RL Num of allocation: 114
# RL Num of allocation: 132
# RL Num of allocation: 132
# epoch: 29
# User: 200 Server: 30 Epoch: 30
# ILP Allocated Num of Users: 52
# Greedy-Ngb Num of allocation: 48
# RL Num of allocation: 122
# RL Num of allocation: 114
# RL Num of allocation: 122
# RL Num of allocation: 122
# epoch: 30
# User: 200 Server: 30 Epoch: 31
# ILP Allocated Num of Users: 61
# Greedy-Ngb Num of allocation: 53
# RL Num of allocation: 128
# RL Num of allocation: 113
# RL Num of allocation: 128
# RL Num of allocation: 128
# epoch: 31
# User: 200 Server: 30 Epoch: 32
# ILP Allocated Num of Users: 63
# Greedy-Ngb Num of allocation: 51
# RL Num of allocation: 130
# RL Num of allocation: 113
# RL Num of allocation: 132
# RL Num of allocation: 132
# epoch: 32
# User: 200 Server: 30 Epoch: 33
# ILP Allocated Num of Users: 63
# Greedy-Ngb Num of allocation: 54
# RL Num of allocation: 143
# RL Num of allocation: 130
# RL Num of allocation: 143
# RL Num of allocation: 143
# epoch: 33
# User: 200 Server: 30 Epoch: 34
# ILP Allocated Num of Users: 56
# Greedy-Ngb Num of allocation: 48
# RL Num of allocation: 105
# RL Num of allocation: 98
# RL Num of allocation: 105
# RL Num of allocation: 105
# epoch: 34
# User: 200 Server: 30 Epoch: 35
# ILP Allocated Num of Users: 56
# Greedy-Ngb Num of allocation: 48
# RL Num of allocation: 121
# RL Num of allocation: 104
# RL Num of allocation: 127
# RL Num of allocation: 127
# epoch: 35
# User: 200 Server: 30 Epoch: 36
# ILP Allocated Num of Users: 62
# Greedy-Ngb Num of allocation: 54
# RL Num of allocation: 136
# RL Num of allocation: 122
# RL Num of allocation: 136
# RL Num of allocation: 136
# epoch: 36
# User: 200 Server: 30 Epoch: 37
# ILP Allocated Num of Users: 64
# Greedy-Ngb Num of allocation: 53
# RL Num of allocation: 136
# RL Num of allocation: 110
# RL Num of allocation: 136
# RL Num of allocation: 136
# epoch: 37
# User: 200 Server: 30 Epoch: 38
# ILP Allocated Num of Users: 62
# Greedy-Ngb Num of allocation: 55
# RL Num of allocation: 133
# RL Num of allocation: 108
# RL Num of allocation: 133
# RL Num of allocation: 133
# epoch: 38
# User: 200 Server: 30 Epoch: 39
# ILP Allocated Num of Users: 60
# Greedy-Ngb Num of allocation: 52
# RL Num of allocation: 122
# RL Num of allocation: 111
# RL Num of allocation: 122
# RL Num of allocation: 122
# epoch: 39
# User: 200 Server: 30 Epoch: 40
# ILP Allocated Num of Users: 55
# Greedy-Ngb Num of allocation: 50
# RL Num of allocation: 120
# RL Num of allocation: 117
# RL Num of allocation: 122
# RL Num of allocation: 122
# epoch: 40
# User: 200 Server: 30 Epoch: 41
# ILP Allocated Num of Users: 60
# Greedy-Ngb Num of allocation: 51
# RL Num of allocation: 122
# RL Num of allocation: 107
# RL Num of allocation: 123
# RL Num of allocation: 123
# epoch: 41
# User: 200 Server: 30 Epoch: 42
# ILP Allocated Num of Users: 59
# Greedy-Ngb Num of allocation: 51
# RL Num of allocation: 141
# RL Num of allocation: 118
# RL Num of allocation: 141
# RL Num of allocation: 141
# epoch: 42
# User: 200 Server: 30 Epoch: 43
# ILP Allocated Num of Users: 65
# Greedy-Ngb Num of allocation: 51
# RL Num of allocation: 141
# RL Num of allocation: 124
# RL Num of allocation: 145
# RL Num of allocation: 145
# epoch: 43
# User: 200 Server: 30 Epoch: 44
# ILP Allocated Num of Users: 60
# Greedy-Ngb Num of allocation: 50
# RL Num of allocation: 144
# RL Num of allocation: 114
# RL Num of allocation: 146
# RL Num of allocation: 146
# epoch: 44
# User: 200 Server: 30 Epoch: 45
# ILP Allocated Num of Users: 56
# Greedy-Ngb Num of allocation: 48
# RL Num of allocation: 103
# RL Num of allocation: 102
# RL Num of allocation: 103
# RL Num of allocation: 103
# epoch: 45
# User: 200 Server: 30 Epoch: 46
# ILP Allocated Num of Users: 58
# Greedy-Ngb Num of allocation: 49
# RL Num of allocation: 139
# RL Num of allocation: 107
# RL Num of allocation: 139
# RL Num of allocation: 139
# epoch: 46
# User: 200 Server: 30 Epoch: 47
# ILP Allocated Num of Users: 61
# Greedy-Ngb Num of allocation: 54
# RL Num of allocation: 125
# RL Num of allocation: 108
# RL Num of allocation: 125
# RL Num of allocation: 125
# epoch: 47
# User: 200 Server: 30 Epoch: 48
# ILP Allocated Num of Users: 66
# Greedy-Ngb Num of allocation: 55
# RL Num of allocation: 125
# RL Num of allocation: 118
# RL Num of allocation: 125
# RL Num of allocation: 125
# epoch: 48
# User: 200 Server: 30 Epoch: 49
# ILP Allocated Num of Users: 54
# Greedy-Ngb Num of allocation: 48
# RL Num of allocation: 113
# RL Num of allocation: 95
# RL Num of allocation: 113
# RL Num of allocation: 113
# epoch: 49
# User: 300 Server: 30 Epoch: 0
# ILP Allocated Num of Users: 68
# Greedy-Ngb Num of allocation: 55
# RL Num of allocation: 184
# RL Num of allocation: 168
# RL Num of allocation: 188
# RL Num of allocation: 188
# epoch: 0
# User: 300 Server: 30 Epoch: 1
# ILP Allocated Num of Users: 70
# Greedy-Ngb Num of allocation: 55
# RL Num of allocation: 191
# RL Num of allocation: 163
# RL Num of allocation: 199
# RL Num of allocation: 199
# epoch: 1
# User: 300 Server: 30 Epoch: 2
# ILP Allocated Num of Users: 66
# Greedy-Ngb Num of allocation: 53
# RL Num of allocation: 185
# RL Num of allocation: 161
# RL Num of allocation: 199
# RL Num of allocation: 199
# epoch: 2
# User: 300 Server: 30 Epoch: 3
# ILP Allocated Num of Users: 71
# Greedy-Ngb Num of allocation: 57
# RL Num of allocation: 196
# RL Num of allocation: 165
# RL Num of allocation: 198
# RL Num of allocation: 198
# epoch: 3
# User: 300 Server: 30 Epoch: 4
# ILP Allocated Num of Users: 66
# Greedy-Ngb Num of allocation: 56
# RL Num of allocation: 194
# RL Num of allocation: 177
# RL Num of allocation: 211
# RL Num of allocation: 211
# epoch: 4
# User: 300 Server: 30 Epoch: 5
# ILP Allocated Num of Users: 65
# Greedy-Ngb Num of allocation: 53
# RL Num of allocation: 183
# RL Num of allocation: 156
# RL Num of allocation: 185
# RL Num of allocation: 185
# epoch: 5
# User: 300 Server: 30 Epoch: 6
# ILP Allocated Num of Users: 68
# Greedy-Ngb Num of allocation: 56
# RL Num of allocation: 188
# RL Num of allocation: 165
# RL Num of allocation: 190
# RL Num of allocation: 190
# epoch: 6
# User: 300 Server: 30 Epoch: 7
# ILP Allocated Num of Users: 70
# Greedy-Ngb Num of allocation: 59
# RL Num of allocation: 175
# RL Num of allocation: 159
# RL Num of allocation: 180
# RL Num of allocation: 180
# epoch: 7
# User: 300 Server: 30 Epoch: 8
# ILP Allocated Num of Users: 67
# Greedy-Ngb Num of allocation: 53
# RL Num of allocation: 206
# RL Num of allocation: 184
# RL Num of allocation: 209
# RL Num of allocation: 209
# epoch: 8
# User: 300 Server: 30 Epoch: 9
# ILP Allocated Num of Users: 60
# Greedy-Ngb Num of allocation: 47
# RL Num of allocation: 179
# RL Num of allocation: 155
# RL Num of allocation: 180
# RL Num of allocation: 180
# epoch: 9
# User: 300 Server: 30 Epoch: 10
# ILP Allocated Num of Users: 66
# Greedy-Ngb Num of allocation: 49
# RL Num of allocation: 193
# RL Num of allocation: 172
# RL Num of allocation: 198
# RL Num of allocation: 198
# epoch: 10
# User: 300 Server: 30 Epoch: 11
# ILP Allocated Num of Users: 64
# Greedy-Ngb Num of allocation: 52
# RL Num of allocation: 179
# RL Num of allocation: 146
# RL Num of allocation: 179
# RL Num of allocation: 179
# epoch: 11
# User: 300 Server: 30 Epoch: 12
# ILP Allocated Num of Users: 65
# Greedy-Ngb Num of allocation: 55
# RL Num of allocation: 209
# RL Num of allocation: 182
# RL Num of allocation: 224
# RL Num of allocation: 224
# epoch: 12
# User: 300 Server: 30 Epoch: 13
# ILP Allocated Num of Users: 66
# Greedy-Ngb Num of allocation: 56
# RL Num of allocation: 156
# RL Num of allocation: 134
# RL Num of allocation: 160
# RL Num of allocation: 160
# epoch: 13
# User: 300 Server: 30 Epoch: 14
# ILP Allocated Num of Users: 60
# Greedy-Ngb Num of allocation: 48
# RL Num of allocation: 181
# RL Num of allocation: 148
# RL Num of allocation: 186
# RL Num of allocation: 186
# epoch: 14
# User: 300 Server: 30 Epoch: 15
# ILP Allocated Num of Users: 71
# Greedy-Ngb Num of allocation: 53
# RL Num of allocation: 221
# RL Num of allocation: 195
# RL Num of allocation: 227
# RL Num of allocation: 227
# epoch: 15
# User: 300 Server: 30 Epoch: 16
# ILP Allocated Num of Users: 62
# Greedy-Ngb Num of allocation: 52
# RL Num of allocation: 172
# RL Num of allocation: 158
# RL Num of allocation: 174
# RL Num of allocation: 174
# epoch: 16
# User: 300 Server: 30 Epoch: 17
# ILP Allocated Num of Users: 70
# Greedy-Ngb Num of allocation: 54
# RL Num of allocation: 205
# RL Num of allocation: 160
# RL Num of allocation: 216
# RL Num of allocation: 216
# epoch: 17
# User: 300 Server: 30 Epoch: 18
# ILP Allocated Num of Users: 60
# Greedy-Ngb Num of allocation: 50
# RL Num of allocation: 204
# RL Num of allocation: 154
# RL Num of allocation: 206
# RL Num of allocation: 206
# epoch: 18
# User: 300 Server: 30 Epoch: 19
# ILP Allocated Num of Users: 61
# Greedy-Ngb Num of allocation: 50
# RL Num of allocation: 194
# RL Num of allocation: 173
# RL Num of allocation: 201
# RL Num of allocation: 201
# epoch: 19
# User: 300 Server: 30 Epoch: 20
# ILP Allocated Num of Users: 62
# Greedy-Ngb Num of allocation: 57
# RL Num of allocation: 176
# RL Num of allocation: 151
# RL Num of allocation: 183
# RL Num of allocation: 183
# epoch: 20
# User: 300 Server: 30 Epoch: 21
# ILP Allocated Num of Users: 69
# Greedy-Ngb Num of allocation: 56
# RL Num of allocation: 198
# RL Num of allocation: 184
# RL Num of allocation: 201
# RL Num of allocation: 201
# epoch: 21
# User: 300 Server: 30 Epoch: 22
# ILP Allocated Num of Users: 65
# Greedy-Ngb Num of allocation: 55
# RL Num of allocation: 200
# RL Num of allocation: 176
# RL Num of allocation: 203
# RL Num of allocation: 203
# epoch: 22
# User: 300 Server: 30 Epoch: 23
# ILP Allocated Num of Users: 70
# Greedy-Ngb Num of allocation: 52
# RL Num of allocation: 205
# RL Num of allocation: 158
# RL Num of allocation: 209
# RL Num of allocation: 209
# epoch: 23
# User: 300 Server: 30 Epoch: 24
# ILP Allocated Num of Users: 62
# Greedy-Ngb Num of allocation: 53
# RL Num of allocation: 205
# RL Num of allocation: 171
# RL Num of allocation: 216
# RL Num of allocation: 216
# epoch: 24
# User: 300 Server: 30 Epoch: 25
# ILP Allocated Num of Users: 68
# Greedy-Ngb Num of allocation: 56
# RL Num of allocation: 164
# RL Num of allocation: 140
# RL Num of allocation: 166
# RL Num of allocation: 166
# epoch: 25
# User: 300 Server: 30 Epoch: 26
# ILP Allocated Num of Users: 66
# Greedy-Ngb Num of allocation: 54
# RL Num of allocation: 204
# RL Num of allocation: 168
# RL Num of allocation: 208
# RL Num of allocation: 208
# epoch: 26
# User: 300 Server: 30 Epoch: 27
# ILP Allocated Num of Users: 64
# Greedy-Ngb Num of allocation: 56
# RL Num of allocation: 173
# RL Num of allocation: 152
# RL Num of allocation: 174
# RL Num of allocation: 174
# epoch: 27
# User: 300 Server: 30 Epoch: 28
# ILP Allocated Num of Users: 68
# Greedy-Ngb Num of allocation: 53
# RL Num of allocation: 211
# RL Num of allocation: 175
# RL Num of allocation: 214
# RL Num of allocation: 214
# epoch: 28
# User: 300 Server: 30 Epoch: 29
# ILP Allocated Num of Users: 69
# Greedy-Ngb Num of allocation: 58
# RL Num of allocation: 171
# RL Num of allocation: 146
# RL Num of allocation: 173
# RL Num of allocation: 173
# epoch: 29
# User: 300 Server: 30 Epoch: 30
# ILP Allocated Num of Users: 65
# Greedy-Ngb Num of allocation: 56
# RL Num of allocation: 200
# RL Num of allocation: 183
# RL Num of allocation: 203
# RL Num of allocation: 203
# epoch: 30
# User: 300 Server: 30 Epoch: 31
# ILP Allocated Num of Users: 71
# Greedy-Ngb Num of allocation: 57
# RL Num of allocation: 208
# RL Num of allocation: 178
# RL Num of allocation: 217
# RL Num of allocation: 217
# epoch: 31
# User: 300 Server: 30 Epoch: 32
# ILP Allocated Num of Users: 65
# Greedy-Ngb Num of allocation: 55
# RL Num of allocation: 163
# RL Num of allocation: 152
# RL Num of allocation: 166
# RL Num of allocation: 166
# epoch: 32
# User: 300 Server: 30 Epoch: 33
# ILP Allocated Num of Users: 67
# Greedy-Ngb Num of allocation: 51
# RL Num of allocation: 204
# RL Num of allocation: 190
# RL Num of allocation: 206
# RL Num of allocation: 206
# epoch: 33
# User: 300 Server: 30 Epoch: 34
# ILP Allocated Num of Users: 68
# Greedy-Ngb Num of allocation: 56
# RL Num of allocation: 185
# RL Num of allocation: 152
# RL Num of allocation: 188
# RL Num of allocation: 188
# epoch: 34
# User: 300 Server: 30 Epoch: 35
# ILP Allocated Num of Users: 68
# Greedy-Ngb Num of allocation: 54
# RL Num of allocation: 183
# RL Num of allocation: 142
# RL Num of allocation: 188
# RL Num of allocation: 188
# epoch: 35
# User: 300 Server: 30 Epoch: 36
# ILP Allocated Num of Users: 72
# Greedy-Ngb Num of allocation: 57
# RL Num of allocation: 188
# RL Num of allocation: 166
# RL Num of allocation: 188
# RL Num of allocation: 188
# epoch: 36
# User: 300 Server: 30 Epoch: 37
# ILP Allocated Num of Users: 63
# Greedy-Ngb Num of allocation: 50
# RL Num of allocation: 173
# RL Num of allocation: 149
# RL Num of allocation: 177
# RL Num of allocation: 177
# epoch: 37
# User: 300 Server: 30 Epoch: 38
# ILP Allocated Num of Users: 67
# Greedy-Ngb Num of allocation: 53
# RL Num of allocation: 188
# RL Num of allocation: 163
# RL Num of allocation: 197
# RL Num of allocation: 197
# epoch: 38
# User: 300 Server: 30 Epoch: 39
# ILP Allocated Num of Users: 68
# Greedy-Ngb Num of allocation: 54
# RL Num of allocation: 189
# RL Num of allocation: 167
# RL Num of allocation: 192
# RL Num of allocation: 192
# epoch: 39
# User: 300 Server: 30 Epoch: 40
# ILP Allocated Num of Users: 68
# Greedy-Ngb Num of allocation: 55
# RL Num of allocation: 189
# RL Num of allocation: 151
# RL Num of allocation: 194
# RL Num of allocation: 194
# epoch: 40
# User: 300 Server: 30 Epoch: 41
# ILP Allocated Num of Users: 66
# Greedy-Ngb Num of allocation: 55
# RL Num of allocation: 174
# RL Num of allocation: 149
# RL Num of allocation: 189
# RL Num of allocation: 189
# epoch: 41
# User: 300 Server: 30 Epoch: 42
# ILP Allocated Num of Users: 68
# Greedy-Ngb Num of allocation: 57
# RL Num of allocation: 198
# RL Num of allocation: 175
# RL Num of allocation: 199
# RL Num of allocation: 199
# epoch: 42
# User: 300 Server: 30 Epoch: 43
# ILP Allocated Num of Users: 68
# Greedy-Ngb Num of allocation: 56
# RL Num of allocation: 187
# RL Num of allocation: 175
# RL Num of allocation: 191
# RL Num of allocation: 191
# epoch: 43
# User: 300 Server: 30 Epoch: 44
# ILP Allocated Num of Users: 67
# Greedy-Ngb Num of allocation: 57
# RL Num of allocation: 208
# RL Num of allocation: 187
# RL Num of allocation: 208
# RL Num of allocation: 208
# epoch: 44
# User: 300 Server: 30 Epoch: 45
# ILP Allocated Num of Users: 62
# Greedy-Ngb Num of allocation: 55
# RL Num of allocation: 191
# RL Num of allocation: 158
# RL Num of allocation: 196
# RL Num of allocation: 196
# epoch: 45
# User: 300 Server: 30 Epoch: 46
# ILP Allocated Num of Users: 68
# Greedy-Ngb Num of allocation: 54
# RL Num of allocation: 202
# RL Num of allocation: 173
# RL Num of allocation: 206
# RL Num of allocation: 206
# epoch: 46
# User: 300 Server: 30 Epoch: 47
# ILP Allocated Num of Users: 64
# Greedy-Ngb Num of allocation: 53
# RL Num of allocation: 193
# RL Num of allocation: 161
# RL Num of allocation: 198
# RL Num of allocation: 198
# epoch: 47
# User: 300 Server: 30 Epoch: 48
# ILP Allocated Num of Users: 64
# Greedy-Ngb Num of allocation: 50
# RL Num of allocation: 191
# RL Num of allocation: 151
# RL Num of allocation: 197
# RL Num of allocation: 197
# epoch: 48
# User: 300 Server: 30 Epoch: 49
# ILP Allocated Num of Users: 61
# Greedy-Ngb Num of allocation: 49
# RL Num of allocation: 175
# RL Num of allocation: 159
# RL Num of allocation: 185
# RL Num of allocation: 185
# epoch: 49
# User: 400 Server: 30 Epoch: 0
# ILP Allocated Num of Users: 74
# Greedy-Ngb Num of allocation: 57
# RL Num of allocation: 235
# RL Num of allocation: 198
# RL Num of allocation: 251
# RL Num of allocation: 251
# epoch: 0
# User: 400 Server: 30 Epoch: 1
# ILP Allocated Num of Users: 69
# Greedy-Ngb Num of allocation: 53
# RL Num of allocation: 211
# RL Num of allocation: 176
# RL Num of allocation: 227
# RL Num of allocation: 227
# epoch: 1
# User: 400 Server: 30 Epoch: 2
# ILP Allocated Num of Users: 74
# Greedy-Ngb Num of allocation: 58
# RL Num of allocation: 252
# RL Num of allocation: 198
# RL Num of allocation: 267
# RL Num of allocation: 267
# epoch: 2
# User: 400 Server: 30 Epoch: 3
# ILP Allocated Num of Users: 72
# Greedy-Ngb Num of allocation: 50
# RL Num of allocation: 270
# RL Num of allocation: 236
# RL Num of allocation: 299
# RL Num of allocation: 299
# epoch: 3
# User: 400 Server: 30 Epoch: 4
# ILP Allocated Num of Users: 66
# Greedy-Ngb Num of allocation: 54
# RL Num of allocation: 259
# RL Num of allocation: 232
# RL Num of allocation: 279
# RL Num of allocation: 279
# epoch: 4
# User: 400 Server: 30 Epoch: 5
# ILP Allocated Num of Users: 70
# Greedy-Ngb Num of allocation: 54
# RL Num of allocation: 236
# RL Num of allocation: 191
# RL Num of allocation: 238
# RL Num of allocation: 238
# epoch: 5
# User: 400 Server: 30 Epoch: 6
# ILP Allocated Num of Users: 69
# Greedy-Ngb Num of allocation: 54
# RL Num of allocation: 271
# RL Num of allocation: 225
# RL Num of allocation: 286
# RL Num of allocation: 286
# epoch: 6
# User: 400 Server: 30 Epoch: 7
# ILP Allocated Num of Users: 67
# Greedy-Ngb Num of allocation: 49
# RL Num of allocation: 245
# RL Num of allocation: 184
# RL Num of allocation: 260
# RL Num of allocation: 260
# epoch: 7
# User: 400 Server: 30 Epoch: 8
# ILP Allocated Num of Users: 69
# Greedy-Ngb Num of allocation: 54
# RL Num of allocation: 229
# RL Num of allocation: 204
# RL Num of allocation: 243
# RL Num of allocation: 243
# epoch: 8
# User: 400 Server: 30 Epoch: 9
# ILP Allocated Num of Users: 67
# Greedy-Ngb Num of allocation: 50
# RL Num of allocation: 242
# RL Num of allocation: 203
# RL Num of allocation: 261
# RL Num of allocation: 261
# epoch: 9
# User: 400 Server: 30 Epoch: 10
# ILP Allocated Num of Users: 70
# Greedy-Ngb Num of allocation: 58
# RL Num of allocation: 251
# RL Num of allocation: 213
# RL Num of allocation: 265
# RL Num of allocation: 265
# epoch: 10
# User: 400 Server: 30 Epoch: 11
# ILP Allocated Num of Users: 68
# Greedy-Ngb Num of allocation: 51
# RL Num of allocation: 238
# RL Num of allocation: 217
# RL Num of allocation: 257
# RL Num of allocation: 257
# epoch: 11
# User: 400 Server: 30 Epoch: 12
# ILP Allocated Num of Users: 69
# Greedy-Ngb Num of allocation: 53
# RL Num of allocation: 271
# RL Num of allocation: 236
# RL Num of allocation: 296
# RL Num of allocation: 296
# epoch: 12
# User: 400 Server: 30 Epoch: 13
# ILP Allocated Num of Users: 71
# Greedy-Ngb Num of allocation: 56
# RL Num of allocation: 225
# RL Num of allocation: 198
# RL Num of allocation: 225
# RL Num of allocation: 225
# epoch: 13
# User: 400 Server: 30 Epoch: 14
# ILP Allocated Num of Users: 72
# Greedy-Ngb Num of allocation: 59
# RL Num of allocation: 270
# RL Num of allocation: 221
# RL Num of allocation: 286
# RL Num of allocation: 286
# epoch: 14
# User: 400 Server: 30 Epoch: 15
# ILP Allocated Num of Users: 71
# Greedy-Ngb Num of allocation: 57
# RL Num of allocation: 240
# RL Num of allocation: 198
# RL Num of allocation: 256
# RL Num of allocation: 256
# epoch: 15
# User: 400 Server: 30 Epoch: 16
# ILP Allocated Num of Users: 66
# Greedy-Ngb Num of allocation: 55
# RL Num of allocation: 230
# RL Num of allocation: 194
# RL Num of allocation: 244
# RL Num of allocation: 244
# epoch: 16
# User: 400 Server: 30 Epoch: 17
# ILP Allocated Num of Users: 67
# Greedy-Ngb Num of allocation: 56
# RL Num of allocation: 274
# RL Num of allocation: 230
# RL Num of allocation: 297
# RL Num of allocation: 297
# epoch: 17
# User: 400 Server: 30 Epoch: 18
# ILP Allocated Num of Users: 69
# Greedy-Ngb Num of allocation: 58
# RL Num of allocation: 267
# RL Num of allocation: 237
# RL Num of allocation: 293
# RL Num of allocation: 293
# epoch: 18
# User: 400 Server: 30 Epoch: 19
# ILP Allocated Num of Users: 71
# Greedy-Ngb Num of allocation: 55
# RL Num of allocation: 242
# RL Num of allocation: 207
# RL Num of allocation: 257
# RL Num of allocation: 257
# epoch: 19
# User: 400 Server: 30 Epoch: 20
# ILP Allocated Num of Users: 66
# Greedy-Ngb Num of allocation: 58
# RL Num of allocation: 263
# RL Num of allocation: 198
# RL Num of allocation: 281
# RL Num of allocation: 281
# epoch: 20
# User: 400 Server: 30 Epoch: 21
# ILP Allocated Num of Users: 67
# Greedy-Ngb Num of allocation: 54
# RL Num of allocation: 268
# RL Num of allocation: 215
# RL Num of allocation: 284
# RL Num of allocation: 284
# epoch: 21
# User: 400 Server: 30 Epoch: 22
# ILP Allocated Num of Users: 65
# Greedy-Ngb Num of allocation: 53
# RL Num of allocation: 246
# RL Num of allocation: 212
# RL Num of allocation: 265
# RL Num of allocation: 265
# epoch: 22
# User: 400 Server: 30 Epoch: 23
# ILP Allocated Num of Users: 68
# Greedy-Ngb Num of allocation: 54
# RL Num of allocation: 269
# RL Num of allocation: 250
# RL Num of allocation: 286
# RL Num of allocation: 286
# epoch: 23
# User: 400 Server: 30 Epoch: 24
# ILP Allocated Num of Users: 66
# Greedy-Ngb Num of allocation: 55
# RL Num of allocation: 220
# RL Num of allocation: 189
# RL Num of allocation: 241
# RL Num of allocation: 241
# epoch: 24
# User: 400 Server: 30 Epoch: 25
# ILP Allocated Num of Users: 65
# Greedy-Ngb Num of allocation: 54
# RL Num of allocation: 236
# RL Num of allocation: 199
# RL Num of allocation: 248
# RL Num of allocation: 248
# epoch: 25
# User: 400 Server: 30 Epoch: 26
# ILP Allocated Num of Users: 65
# Greedy-Ngb Num of allocation: 49
# RL Num of allocation: 230
# RL Num of allocation: 188
# RL Num of allocation: 244
# RL Num of allocation: 244
# epoch: 26
# User: 400 Server: 30 Epoch: 27
# ILP Allocated Num of Users: 69
# Greedy-Ngb Num of allocation: 51
# RL Num of allocation: 246
# RL Num of allocation: 209
# RL Num of allocation: 262
# RL Num of allocation: 262
# epoch: 27
# User: 400 Server: 30 Epoch: 28
# ILP Allocated Num of Users: 69
# Greedy-Ngb Num of allocation: 58
# RL Num of allocation: 246
# RL Num of allocation: 227
# RL Num of allocation: 264
# RL Num of allocation: 264
# epoch: 28
# User: 400 Server: 30 Epoch: 29
# ILP Allocated Num of Users: 65
# Greedy-Ngb Num of allocation: 57
# RL Num of allocation: 281
# RL Num of allocation: 234
# RL Num of allocation: 291
# RL Num of allocation: 291
# epoch: 29
# User: 400 Server: 30 Epoch: 30
# ILP Allocated Num of Users: 66
# Greedy-Ngb Num of allocation: 51
# RL Num of allocation: 242
# RL Num of allocation: 210
# RL Num of allocation: 259
# RL Num of allocation: 259
# epoch: 30
# User: 400 Server: 30 Epoch: 31
# ILP Allocated Num of Users: 73
# Greedy-Ngb Num of allocation: 62
# RL Num of allocation: 250
# RL Num of allocation: 232
# RL Num of allocation: 261
# RL Num of allocation: 261
# epoch: 31
# User: 400 Server: 30 Epoch: 32
# ILP Allocated Num of Users: 67
# Greedy-Ngb Num of allocation: 56
# RL Num of allocation: 247
# RL Num of allocation: 226
# RL Num of allocation: 264
# RL Num of allocation: 264
# epoch: 32
# User: 400 Server: 30 Epoch: 33
# ILP Allocated Num of Users: 71
# Greedy-Ngb Num of allocation: 59
# RL Num of allocation: 235
# RL Num of allocation: 196
# RL Num of allocation: 246
# RL Num of allocation: 246
# epoch: 33
# User: 400 Server: 30 Epoch: 34
# ILP Allocated Num of Users: 71
# Greedy-Ngb Num of allocation: 54
# RL Num of allocation: 274
# RL Num of allocation: 214
# RL Num of allocation: 305
# RL Num of allocation: 305
# epoch: 34
# User: 400 Server: 30 Epoch: 35
# ILP Allocated Num of Users: 71
# Greedy-Ngb Num of allocation: 56
# RL Num of allocation: 247
# RL Num of allocation: 198
# RL Num of allocation: 251
# RL Num of allocation: 251
# epoch: 35
# User: 400 Server: 30 Epoch: 36
# ILP Allocated Num of Users: 69
# Greedy-Ngb Num of allocation: 57
# RL Num of allocation: 221
# RL Num of allocation: 189
# RL Num of allocation: 240
# RL Num of allocation: 240
# epoch: 36
# User: 400 Server: 30 Epoch: 37
# ILP Allocated Num of Users: 66
# Greedy-Ngb Num of allocation: 52
# RL Num of allocation: 257
# RL Num of allocation: 227
# RL Num of allocation: 279
# RL Num of allocation: 279
# epoch: 37
# User: 400 Server: 30 Epoch: 38
# ILP Allocated Num of Users: 66
# Greedy-Ngb Num of allocation: 52
# RL Num of allocation: 224
# RL Num of allocation: 199
# RL Num of allocation: 231
# RL Num of allocation: 231
# epoch: 38
# User: 400 Server: 30 Epoch: 39
# ILP Allocated Num of Users: 65
# Greedy-Ngb Num of allocation: 56
# RL Num of allocation: 222
# RL Num of allocation: 189
# RL Num of allocation: 229
# RL Num of allocation: 229
# epoch: 39
# User: 400 Server: 30 Epoch: 40
# ILP Allocated Num of Users: 69
# Greedy-Ngb Num of allocation: 57
# RL Num of allocation: 191
# RL Num of allocation: 180
# RL Num of allocation: 200
# RL Num of allocation: 200
# epoch: 40
# User: 400 Server: 30 Epoch: 41
# ILP Allocated Num of Users: 67
# Greedy-Ngb Num of allocation: 53
# RL Num of allocation: 209
# RL Num of allocation: 167
# RL Num of allocation: 235
# RL Num of allocation: 235
# epoch: 41
# User: 400 Server: 30 Epoch: 42
# ILP Allocated Num of Users: 72
# Greedy-Ngb Num of allocation: 55
# RL Num of allocation: 243
# RL Num of allocation: 178
# RL Num of allocation: 246
# RL Num of allocation: 246
# epoch: 42
# User: 400 Server: 30 Epoch: 43
# ILP Allocated Num of Users: 66
# Greedy-Ngb Num of allocation: 58
# RL Num of allocation: 230
# RL Num of allocation: 196
# RL Num of allocation: 259
# RL Num of allocation: 259
# epoch: 43
# User: 400 Server: 30 Epoch: 44
# ILP Allocated Num of Users: 68
# Greedy-Ngb Num of allocation: 55
# RL Num of allocation: 247
# RL Num of allocation: 216
# RL Num of allocation: 268
# RL Num of allocation: 268
# epoch: 44
# User: 400 Server: 30 Epoch: 45
# ILP Allocated Num of Users: 69
# Greedy-Ngb Num of allocation: 54
# RL Num of allocation: 224
# RL Num of allocation: 189
# RL Num of allocation: 241
# RL Num of allocation: 241
# epoch: 45
# User: 400 Server: 30 Epoch: 46
# ILP Allocated Num of Users: 71
# Greedy-Ngb Num of allocation: 54
# RL Num of allocation: 254
# RL Num of allocation: 197
# RL Num of allocation: 262
# RL Num of allocation: 262
# epoch: 46
# User: 400 Server: 30 Epoch: 47
# ILP Allocated Num of Users: 69
# Greedy-Ngb Num of allocation: 53
# RL Num of allocation: 238
# RL Num of allocation: 203
# RL Num of allocation: 257
# RL Num of allocation: 257
# epoch: 47
# User: 400 Server: 30 Epoch: 48
# ILP Allocated Num of Users: 67
# Greedy-Ngb Num of allocation: 53
# RL Num of allocation: 249
# RL Num of allocation: 226
# RL Num of allocation: 275
# RL Num of allocation: 275
# epoch: 48
# User: 400 Server: 30 Epoch: 49
# ILP Allocated Num of Users: 67
# Greedy-Ngb Num of allocation: 56
# RL Num of allocation: 202
# RL Num of allocation: 175
# RL Num of allocation: 212
# RL Num of allocation: 212
# epoch: 49
# User: 500 Server: 30 Epoch: 0
# ILP Allocated Num of Users: 67
# Greedy-Ngb Num of allocation: 52
# RL Num of allocation: 279
# RL Num of allocation: 205
# RL Num of allocation: 298
# RL Num of allocation: 298
# epoch: 0
# User: 500 Server: 30 Epoch: 1
# ILP Allocated Num of Users: 66
# Greedy-Ngb Num of allocation: 53
# RL Num of allocation: 285
# RL Num of allocation: 262
# RL Num of allocation: 304
# RL Num of allocation: 304
# epoch: 1
# User: 500 Server: 30 Epoch: 2
# ILP Allocated Num of Users: 67
# Greedy-Ngb Num of allocation: 53
# RL Num of allocation: 295
# RL Num of allocation: 252
# RL Num of allocation: 341
# RL Num of allocation: 341
# epoch: 2
# User: 500 Server: 30 Epoch: 3
# ILP Allocated Num of Users: 65
# Greedy-Ngb Num of allocation: 51
# RL Num of allocation: 299
# RL Num of allocation: 261
# RL Num of allocation: 347
# RL Num of allocation: 347
# epoch: 3
# User: 500 Server: 30 Epoch: 4
# ILP Allocated Num of Users: 70
# Greedy-Ngb Num of allocation: 57
# RL Num of allocation: 295
# RL Num of allocation: 254
# RL Num of allocation: 328
# RL Num of allocation: 328
# epoch: 4
# User: 500 Server: 30 Epoch: 5
# ILP Allocated Num of Users: 68
# Greedy-Ngb Num of allocation: 52
# RL Num of allocation: 306
# RL Num of allocation: 269
# RL Num of allocation: 340
# RL Num of allocation: 340
# epoch: 5
# User: 500 Server: 30 Epoch: 6
# ILP Allocated Num of Users: 63
# Greedy-Ngb Num of allocation: 44
# RL Num of allocation: 276
# RL Num of allocation: 232
# RL Num of allocation: 304
# RL Num of allocation: 304
# epoch: 6
# User: 500 Server: 30 Epoch: 7
# ILP Allocated Num of Users: 72
# Greedy-Ngb Num of allocation: 55
# RL Num of allocation: 286
# RL Num of allocation: 263
# RL Num of allocation: 312
# RL Num of allocation: 312
# epoch: 7
# User: 500 Server: 30 Epoch: 8
# ILP Allocated Num of Users: 67
# Greedy-Ngb Num of allocation: 54
# RL Num of allocation: 282
# RL Num of allocation: 248
# RL Num of allocation: 330
# RL Num of allocation: 331
# epoch: 8
# User: 500 Server: 30 Epoch: 9
# ILP Allocated Num of Users: 67
# Greedy-Ngb Num of allocation: 59
# RL Num of allocation: 284
# RL Num of allocation: 264
# RL Num of allocation: 311
# RL Num of allocation: 311
# epoch: 9
# User: 500 Server: 30 Epoch: 10
# ILP Allocated Num of Users: 72
# Greedy-Ngb Num of allocation: 60
# RL Num of allocation: 293
# RL Num of allocation: 275
# RL Num of allocation: 321
# RL Num of allocation: 321
# epoch: 10
# User: 500 Server: 30 Epoch: 11
# ILP Allocated Num of Users: 68
# Greedy-Ngb Num of allocation: 51
# RL Num of allocation: 268
# RL Num of allocation: 247
# RL Num of allocation: 298
# RL Num of allocation: 298
# epoch: 11
# User: 500 Server: 30 Epoch: 12
# ILP Allocated Num of Users: 65
# Greedy-Ngb Num of allocation: 49
# RL Num of allocation: 280
# RL Num of allocation: 229
# RL Num of allocation: 297
# RL Num of allocation: 297
# epoch: 12
# User: 500 Server: 30 Epoch: 13
# ILP Allocated Num of Users: 71
# Greedy-Ngb Num of allocation: 55
# RL Num of allocation: 299
# RL Num of allocation: 240
# RL Num of allocation: 335
# RL Num of allocation: 335
# epoch: 13
# User: 500 Server: 30 Epoch: 14
# ILP Allocated Num of Users: 70
# Greedy-Ngb Num of allocation: 52
# RL Num of allocation: 264
# RL Num of allocation: 236
# RL Num of allocation: 283
# RL Num of allocation: 283
# epoch: 14
# User: 500 Server: 30 Epoch: 15
# ILP Allocated Num of Users: 66
# Greedy-Ngb Num of allocation: 53
# RL Num of allocation: 279
# RL Num of allocation: 251
# RL Num of allocation: 302
# RL Num of allocation: 302
# epoch: 15
# User: 500 Server: 30 Epoch: 16
# ILP Allocated Num of Users: 70
# Greedy-Ngb Num of allocation: 51
# RL Num of allocation: 281
# RL Num of allocation: 265
# RL Num of allocation: 323
# RL Num of allocation: 323
# epoch: 16
# User: 500 Server: 30 Epoch: 17
# ILP Allocated Num of Users: 67
# Greedy-Ngb Num of allocation: 49
# RL Num of allocation: 309
# RL Num of allocation: 264
# RL Num of allocation: 341
# RL Num of allocation: 341
# epoch: 17
# User: 500 Server: 30 Epoch: 18
# ILP Allocated Num of Users: 64
# Greedy-Ngb Num of allocation: 51
# RL Num of allocation: 270
# RL Num of allocation: 234
# RL Num of allocation: 296
# RL Num of allocation: 296
# epoch: 18
# User: 500 Server: 30 Epoch: 19
# ILP Allocated Num of Users: 65
# Greedy-Ngb Num of allocation: 53
# RL Num of allocation: 329
# RL Num of allocation: 256
# RL Num of allocation: 377
# RL Num of allocation: 377
# epoch: 19
# User: 500 Server: 30 Epoch: 20
# ILP Allocated Num of Users: 68
# Greedy-Ngb Num of allocation: 57
# RL Num of allocation: 310
# RL Num of allocation: 268
# RL Num of allocation: 350
# RL Num of allocation: 350
# epoch: 20
# User: 500 Server: 30 Epoch: 21
# ILP Allocated Num of Users: 71
# Greedy-Ngb Num of allocation: 53
# RL Num of allocation: 305
# RL Num of allocation: 244
# RL Num of allocation: 326
# RL Num of allocation: 326
# epoch: 21
# User: 500 Server: 30 Epoch: 22
# ILP Allocated Num of Users: 68
# Greedy-Ngb Num of allocation: 52
# RL Num of allocation: 277
# RL Num of allocation: 251
# RL Num of allocation: 303
# RL Num of allocation: 303
# epoch: 22
# User: 500 Server: 30 Epoch: 23
# ILP Allocated Num of Users: 67
# Greedy-Ngb Num of allocation: 50
# RL Num of allocation: 299
# RL Num of allocation: 269
# RL Num of allocation: 330
# RL Num of allocation: 330
# epoch: 23
# User: 500 Server: 30 Epoch: 24
# ILP Allocated Num of Users: 69
# Greedy-Ngb Num of allocation: 55
# RL Num of allocation: 310
# RL Num of allocation: 256
# RL Num of allocation: 349
# RL Num of allocation: 349
# epoch: 24
# User: 500 Server: 30 Epoch: 25
# ILP Allocated Num of Users: 66
# Greedy-Ngb Num of allocation: 55
# RL Num of allocation: 277
# RL Num of allocation: 257
# RL Num of allocation: 314
# RL Num of allocation: 314
# epoch: 25
# User: 500 Server: 30 Epoch: 26
# ILP Allocated Num of Users: 69
# Greedy-Ngb Num of allocation: 52
# RL Num of allocation: 277
# RL Num of allocation: 263
# RL Num of allocation: 301
# RL Num of allocation: 301
# epoch: 26
# User: 500 Server: 30 Epoch: 27
# ILP Allocated Num of Users: 66
# Greedy-Ngb Num of allocation: 51
# RL Num of allocation: 256
# RL Num of allocation: 214
# RL Num of allocation: 280
# RL Num of allocation: 280
# epoch: 27
# User: 500 Server: 30 Epoch: 28
# ILP Allocated Num of Users: 69
# Greedy-Ngb Num of allocation: 50
# RL Num of allocation: 314
# RL Num of allocation: 262
# RL Num of allocation: 345
# RL Num of allocation: 345
# epoch: 28
# User: 500 Server: 30 Epoch: 29
# ILP Allocated Num of Users: 71
# Greedy-Ngb Num of allocation: 55
# RL Num of allocation: 293
# RL Num of allocation: 227
# RL Num of allocation: 310
# RL Num of allocation: 310
# epoch: 29
# User: 500 Server: 30 Epoch: 30
# ILP Allocated Num of Users: 66
# Greedy-Ngb Num of allocation: 53
# RL Num of allocation: 298
# RL Num of allocation: 273
# RL Num of allocation: 338
# RL Num of allocation: 338
# epoch: 30
# User: 500 Server: 30 Epoch: 31
# ILP Allocated Num of Users: 67
# Greedy-Ngb Num of allocation: 52
# RL Num of allocation: 290
# RL Num of allocation: 224
# RL Num of allocation: 310
# RL Num of allocation: 310
# epoch: 31
# User: 500 Server: 30 Epoch: 32
# ILP Allocated Num of Users: 72
# Greedy-Ngb Num of allocation: 56
# RL Num of allocation: 281
# RL Num of allocation: 249
# RL Num of allocation: 309
# RL Num of allocation: 309
# epoch: 32
# User: 500 Server: 30 Epoch: 33
# ILP Allocated Num of Users: 68
# Greedy-Ngb Num of allocation: 54
# RL Num of allocation: 286
# RL Num of allocation: 248
# RL Num of allocation: 316
# RL Num of allocation: 316
# epoch: 33
# User: 500 Server: 30 Epoch: 34
# ILP Allocated Num of Users: 72
# Greedy-Ngb Num of allocation: 55
# RL Num of allocation: 275
# RL Num of allocation: 246
# RL Num of allocation: 297
# RL Num of allocation: 297
# epoch: 34
# User: 500 Server: 30 Epoch: 35
# ILP Allocated Num of Users: 73
# Greedy-Ngb Num of allocation: 49
# RL Num of allocation: 301
# RL Num of allocation: 238
# RL Num of allocation: 319
# RL Num of allocation: 319
# epoch: 35
# User: 500 Server: 30 Epoch: 36
# ILP Allocated Num of Users: 66
# Greedy-Ngb Num of allocation: 54
# RL Num of allocation: 281
# RL Num of allocation: 231
# RL Num of allocation: 305
# RL Num of allocation: 305
# epoch: 36
# User: 500 Server: 30 Epoch: 37
# ILP Allocated Num of Users: 68
# Greedy-Ngb Num of allocation: 58
# RL Num of allocation: 322
# RL Num of allocation: 265
# RL Num of allocation: 365
# RL Num of allocation: 365
# epoch: 37
# User: 500 Server: 30 Epoch: 38
# ILP Allocated Num of Users: 68
# Greedy-Ngb Num of allocation: 55
# RL Num of allocation: 292
# RL Num of allocation: 270
# RL Num of allocation: 340
# RL Num of allocation: 340
# epoch: 38
# User: 500 Server: 30 Epoch: 39
# ILP Allocated Num of Users: 70
# Greedy-Ngb Num of allocation: 52
# RL Num of allocation: 272
# RL Num of allocation: 229
# RL Num of allocation: 305
# RL Num of allocation: 305
# epoch: 39
# User: 500 Server: 30 Epoch: 40
# ILP Allocated Num of Users: 67
# Greedy-Ngb Num of allocation: 52
# RL Num of allocation: 251
# RL Num of allocation: 216
# RL Num of allocation: 266
# RL Num of allocation: 266
# epoch: 40
# User: 500 Server: 30 Epoch: 41
# ILP Allocated Num of Users: 68
# Greedy-Ngb Num of allocation: 57
# RL Num of allocation: 275
# RL Num of allocation: 221
# RL Num of allocation: 301
# RL Num of allocation: 301
# epoch: 41
# User: 500 Server: 30 Epoch: 42
# ILP Allocated Num of Users: 74
# Greedy-Ngb Num of allocation: 64
# RL Num of allocation: 289
# RL Num of allocation: 227
# RL Num of allocation: 321
# RL Num of allocation: 321
# epoch: 42
# User: 500 Server: 30 Epoch: 43
# ILP Allocated Num of Users: 70
# Greedy-Ngb Num of allocation: 55
# RL Num of allocation: 296
# RL Num of allocation: 215
# RL Num of allocation: 327
# RL Num of allocation: 327
# epoch: 43
# User: 500 Server: 30 Epoch: 44
# ILP Allocated Num of Users: 74
# Greedy-Ngb Num of allocation: 56
# RL Num of allocation: 254
# RL Num of allocation: 235
# RL Num of allocation: 293
# RL Num of allocation: 293
# epoch: 44
# User: 500 Server: 30 Epoch: 45
# ILP Allocated Num of Users: 72
# Greedy-Ngb Num of allocation: 59
# RL Num of allocation: 311
# RL Num of allocation: 265
# RL Num of allocation: 355
# RL Num of allocation: 355
# epoch: 45
# User: 500 Server: 30 Epoch: 46
# ILP Allocated Num of Users: 72
# Greedy-Ngb Num of allocation: 60
# RL Num of allocation: 299
# RL Num of allocation: 246
# RL Num of allocation: 318
# RL Num of allocation: 318
# epoch: 46
# User: 500 Server: 30 Epoch: 47
# ILP Allocated Num of Users: 69
# Greedy-Ngb Num of allocation: 51
# RL Num of allocation: 278
# RL Num of allocation: 246
# RL Num of allocation: 318
# RL Num of allocation: 318
# epoch: 47
# User: 500 Server: 30 Epoch: 48
# ILP Allocated Num of Users: 71
# Greedy-Ngb Num of allocation: 57
# RL Num of allocation: 282
# RL Num of allocation: 212
# RL Num of allocation: 300
# RL Num of allocation: 300
# epoch: 48
# User: 500 Server: 30 Epoch: 49
# ILP Allocated Num of Users: 69
# Greedy-Ngb Num of allocation: 54
# RL Num of allocation: 283
# RL Num of allocation: 238
# RL Num of allocation: 319
# RL Num of allocation: 319
# epoch: 49

# %%
result_user
# Out:
#       user  server  ilp_user  ilp_time  greedy_user  greedy_time  rl_act_user  \
# 0    100.0    30.0      45.0  6.897818         41.0     0.026541         77.0
# 1    100.0    30.0      42.0  0.140814         41.0     0.020789         50.0
# 2    100.0    30.0      40.0  0.167810         35.0     0.025199         63.0
# 3    100.0    30.0      43.0  0.164766         42.0     0.026608         70.0
# 4    100.0    30.0      51.0  0.149066         43.0     0.025358         75.0
# ..     ...     ...       ...       ...          ...          ...          ...
# 245  500.0    30.0      72.0  0.747710         59.0     0.127495        311.0
# 246  500.0    30.0      72.0  0.840029         60.0     0.127422        299.0
# 247  500.0    30.0      69.0  0.784908         51.0     0.125308        278.0
# 248  500.0    30.0      71.0  0.763599         57.0     0.117507        282.0
# 249  500.0    30.0      69.0  0.829659         54.0     0.113053        283.0
#
#      rl_act_time  rl_und_user  rl_und_time  rl_prop_user  rl_prop_time  \
# 0       0.167978         70.0     0.012435          77.0      0.019812
# 1       0.011666         49.0     0.011208          50.0      0.011194
# 2       0.011811         59.0     0.011184          64.0      0.011244
# 3       0.011779         67.0     0.011254          70.0      0.011260
# 4       0.011712         72.0     0.011280          75.0      0.011247
# ..           ...          ...          ...           ...           ...
# 245     0.014970        265.0     0.014544         355.0      0.014694
# 246     0.014259        246.0     0.013873         318.0      0.014070
# 247     0.014771        246.0     0.014326         318.0      0.014450
# 248     0.014226        212.0     0.014077         300.0      0.014254
# 249     0.014355        238.0     0.014352         319.0      0.014387
#
#      rl_thres10_user  rl_thres10_time
# 0               77.0         0.012341
# 1               50.0         0.011300
# 2               64.0         0.011242
# 3               70.0         0.011286
# 4               75.0         0.011284
# ..               ...              ...
# 245            355.0         0.014674
# 246            318.0         0.014003
# 247            318.0         0.014440
# 248            300.0         0.014328
# 249            319.0         0.014495
#
# [250 rows x 14 columns]
